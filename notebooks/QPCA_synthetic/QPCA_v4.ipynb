# %% [markdown]
# Simualtor for QPCA with a fine tuned circuit and simualtor ready for backend and API for real quanutm computer

# %%
# Define a local backend
from qiskit_ibm_runtime.fake_provider import FakeManilaV2
backend = FakeManilaV2()

# Or define a real backend
# from qiskit_ibm_runtime import QiskitRuntimeService
# service = QiskitRuntimeService()
# backend = service.least_busy(operational=True, simulator=False)

# Circuits and parameters must obey the Instruction Set Architecture (ISA) of a particular backend.
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
 
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)
 
isa_observable = op.apply_layout(isa_circuit.layout)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      11 from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
#      13 pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
# ---> 14 isa_circuit = pm.run(circuit)
#      16 isa_observable = op.apply_layout(isa_circuit.layout)
#
# NameError: name 'circuit' is not defined

# %%
#I use expectation values of the PCA so this is relevant 
#very similar to the previous code but with new specific functions of 2025 try and run the iris data set on this 

from qiskit_ibm_runtime import EstimatorV2 as Estimator
 
estimator = Estimator(backend, options={"default_shots": int(1e4)})
job = estimator.run([(isa_circuit, isa_observable)])
 
 
# Get results for the first (and only) PUB
pub_result = job.result()[0]
 
print(f">>> Expectation value: {pub_result.data.evs}")
